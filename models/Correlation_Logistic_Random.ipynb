# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
import pandas as pd
import sys
import os
from pyspark.sql.functions import isnan, when, count, col
from pyspark.sql.functions import to_timestamp
import time
from pyspark.sql import functions as fn

import datetime
from pyspark.sql.functions import year, month, dayofmonth, hour, minute, second
from pyspark.mllib.stat import Statistics
import pandas as pd

# %%
spark = SparkSession.builder.appName('data-cleaning').\
                        config("spark.executor.instances", '3').\
                        config("spark.executor.memory", '40g').\
                        config('spark.executor.cores', '5').\
                        config('spark.cores.max', '5').appName('data_clean').\
                        getOrCreate()

# %%
sqlContext = SQLContext(spark.sparkContext)

# %%
train_data = spark.read.format('csv').option('header', 'true').load('../modeled_data/spark_data3.csv')

# %%
train_data.count()
# Out:
# 77157

# %%
train_data = train_data.drop('latitude18').drop('longitude19').drop('_c0').withColumnRenamed('latitude5', 'latitude').withColumnRenamed('longitude4', 'longitude')
train_data.limit(5).toPandas()
# Out:
#               device_id label_id               app_id event_id gender age  \
# 0  -6754902882206380496      704  -145658454112781034    35963      M  33
# 1   5416618857406916680      209  2460654806659045896  1773101      M  30
# 2   5416618857406916680      209  2460654806659045896  1773101      M  30
# 3   1698428484639625968      303  -145658454112781034    37174      M  27
# 4   1698428484639625968      303  -145658454112781034    37174      M  27
#
#     group            timestamp longitude latitude    ...          town  \
# 0  M32-38  2016-05-01 08:55:39    106.56    29.53    ...     Chongqing
# 1  M29-31  2016-05-05 12:08:32    106.56    29.53    ...     Chongqing
# 2  M29-31  2016-05-05 12:08:32    106.56    29.53    ...     Chongqing
# 3  M27-28  2016-05-06 07:57:01    116.21    34.26    ...         Henan
# 4  M27-28  2016-05-06 07:57:01    116.21    34.26    ...         Henan
#
#   country  year month day hour minute seconds time_of_day age_group
# 0   China  2016     5   1    8     55      39     morning     26-35
# 1   China  2016     5   5   12      8      32     morning     26-35
# 2   China  2016     5   5   12      8      32     morning     26-35
# 3   China  2016     5   6    7     57       1     morning     26-35
# 4   China  2016     5   6    7     57       1     morning     26-35
#
# [5 rows x 26 columns]

# %%
training, test = train_data.randomSplit([0.8, 0.2], 0)

# %%
training.count()
# Out:
# 61677

# %%
test.count()
# Out:
# 15480

# %%
from pyspark.sql.types import FloatType
from pyspark.sql.types import IntegerType

float_columns = ['device_id', 'app_id', 'label_id', 'event_id', 'longitude', 'latitude']
int_columns = ['is_active', 'age', 'is_installed', 'day', 'hour', 'minute', 'seconds']
string_columns = ['gender', 'group', 'category', 'phone_brand', 'device_model', 'town', 'country']

training = train_data.select(*(col(c).cast("float").alias(c) for c in float_columns), \
                                                 *(col(c).cast("int").alias(c) for c in int_columns), \
                                                 *(col(c).alias(c) for c in string_columns))
test = train_data.select(*(col(c).cast("float").alias(c) for c in float_columns), \
                                                 *(col(c).cast("int").alias(c) for c in int_columns), \
                                                 *(col(c).alias(c) for c in string_columns))

# %%
training.printSchema()
# Out:
# root
#  |-- device_id: float (nullable = true)
#  |-- app_id: float (nullable = true)
#  |-- label_id: float (nullable = true)
#  |-- event_id: float (nullable = true)
#  |-- longitude: float (nullable = true)
#  |-- latitude: float (nullable = true)
#  |-- is_active: integer (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- is_installed: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- minute: integer (nullable = true)
#  |-- seconds: integer (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- group: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- phone_brand: string (nullable = true)
#  |-- device_model: string (nullable = true)
#  |-- town: string (nullable = true)
#  |-- country: string (nullable = true)

# %%
#Correlation
indexer = feature.StringIndexer(inputCol="gender", outputCol="gender_label")
category = feature.StringIndexer(inputCol='category', outputCol='category_encoded')
brand = feature.StringIndexer(inputCol='phone_brand', outputCol='phone_brand_encoded')
group = feature.StringIndexer(inputCol='group', outputCol='group_encoded')
is_active = feature.StringIndexer(inputCol='is_active', outputCol='is_active_encoded')
device_model = feature.StringIndexer(inputCol='device_model', outputCol='device_model_encoded')
town_model = feature.StringIndexer(inputCol='town', outputCol='town_encoded')
country_model = feature.StringIndexer(inputCol='country', outputCol='country_encoded')

correlation_pipeline = Pipeline(stages=[indexer, category, brand, group, is_active, device_model, town_model, country_model])
encoded_data = correlation_pipeline.fit(training).transform(training)

encoded_data = encoded_data['gender_label','device_id', 'app_id', 'category_encoded', 'phone_brand_encoded', 'group_encoded', 'is_active_encoded', 'device_model_encoded',\
                           'town_encoded', 'country_encoded', 'label_id', 'event_id', 'longitude', 'latitude', 'day', 'hour', 'minute']
col_names = encoded_data.columns
features = encoded_data.rdd.map(lambda row: row[0:])
features
corr_mat=Statistics.corr(features, method="pearson")
corr_df = pd.DataFrame(corr_mat)

corr_df.columns = col_names

corr = corr_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_852eb202_6bbe_11e9_80b9_0242ac11000brow0_col0 {
#             background-color:  #b40426;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow0_col1 {
#             background-color:  #6180e9;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow0_col2 {
#             background-color:  #4055c8;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow0_col3 {
#             background-color:  #afcafc;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow0_col4 {
#             background-color:  #5b7ae5;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow0_col5 {
#             background-color:  #cd423b;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow0_col6 {
#             background-color:  #80a3fa;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow0_col7 {
#             background-color:  #465ecf;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow0_col8 {
#             background-color:  #6a8bef;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow0_col9 {
#             background-color:  #dedcdb;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow0_col10 {
#             background-color:  #dadce0;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow0_col11 {
#             background-color:  #4055c8;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow0_col12 {
#             background-color:  #d3dbe7;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow0_col13 {
#             background-color:  #c7d7f0;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow0_col14 {
#             background-color:  #4e68d8;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow0_col15 {
#             background-color:  #445acc;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow0_col16 {
#             background-color:  #465ecf;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow1_col0 {
#             background-color:  #5b7ae5;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow1_col1 {
#             background-color:  #b40426;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow1_col2 {
#             background-color:  #4e68d8;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow1_col3 {
#             background-color:  #cad8ef;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow1_col4 {
#             background-color:  #5673e0;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow1_col5 {
#             background-color:  #4b64d5;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow1_col6 {
#             background-color:  #536edd;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow1_col7 {
#             background-color:  #4358cb;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow1_col8 {
#             background-color:  #4e68d8;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow1_col9 {
#             background-color:  #dfdbd9;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow1_col10 {
#             background-color:  #c3d5f4;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow1_col11 {
#             background-color:  #465ecf;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow1_col12 {
#             background-color:  #d4dbe6;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow1_col13 {
#             background-color:  #c5d6f2;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow1_col14 {
#             background-color:  #4f69d9;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow1_col15 {
#             background-color:  #5470de;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow1_col16 {
#             background-color:  #5673e0;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow2_col0 {
#             background-color:  #4c66d6;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow2_col1 {
#             background-color:  #5f7fe8;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow2_col2 {
#             background-color:  #b40426;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow2_col3 {
#             background-color:  #bad0f8;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow2_col4 {
#             background-color:  #6788ee;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow2_col5 {
#             background-color:  #465ecf;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow2_col6 {
#             background-color:  #8db0fe;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow2_col7 {
#             background-color:  #5572df;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow2_col8 {
#             background-color:  #5f7fe8;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow2_col9 {
#             background-color:  #d8dce2;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow2_col10 {
#             background-color:  #bbd1f8;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow2_col11 {
#             background-color:  #4055c8;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow2_col12 {
#             background-color:  #d8dce2;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow2_col13 {
#             background-color:  #cbd8ee;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow2_col14 {
#             background-color:  #4c66d6;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow2_col15 {
#             background-color:  #4e68d8;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow2_col16 {
#             background-color:  #5572df;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow3_col0 {
#             background-color:  #3b4cc0;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow3_col1 {
#             background-color:  #688aef;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow3_col2 {
#             background-color:  #3d50c3;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow3_col3 {
#             background-color:  #b40426;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow3_col4 {
#             background-color:  #779af7;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow3_col5 {
#             background-color:  #4358cb;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow3_col6 {
#             background-color:  #5a78e4;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow3_col7 {
#             background-color:  #5d7ce6;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow3_col8 {
#             background-color:  #7699f6;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow3_col9 {
#             background-color:  #d8dce2;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow3_col10 {
#             background-color:  #3b4cc0;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow3_col11 {
#             background-color:  #4f69d9;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow3_col12 {
#             background-color:  #dbdcde;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow3_col13 {
#             background-color:  #d6dce4;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow3_col14 {
#             background-color:  #4e68d8;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow3_col15 {
#             background-color:  #5875e1;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow3_col16 {
#             background-color:  #6485ec;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow4_col0 {
#             background-color:  #3b4cc0;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow4_col1 {
#             background-color:  #3c4ec2;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow4_col2 {
#             background-color:  #3b4cc0;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow4_col3 {
#             background-color:  #c4d5f3;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow4_col4 {
#             background-color:  #b40426;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow4_col5 {
#             background-color:  #455cce;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow4_col6 {
#             background-color:  #6788ee;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000brow4_col7 {
#             background-color:  #e57058;
#         }    #T_852eb202_6bbe_11e9_80b9_0242ac11000

# %%
from pyspark.ml import Pipeline
from pyspark.ml import feature
from pyspark.ml import classification
from pyspark.ml.evaluation import BinaryClassificationEvaluator, \
    MulticlassClassificationEvaluator, \
    RegressionEvaluator

# %%
#Logistic
indexer = feature.StringIndexer(inputCol="gender", outputCol="gender_label")
category = feature.StringIndexer(inputCol='category', outputCol='category_encoded')
brand = feature.StringIndexer(inputCol='phone_brand', outputCol='phone_brand_encoded')
group = feature.StringIndexer(inputCol='group', outputCol='group_encoded')
is_active = feature.StringIndexer(inputCol='is_active', outputCol='is_active_encoded')
device_model = feature.StringIndexer(inputCol='device_model', outputCol='device_model_encoded')
town_model = feature.StringIndexer(inputCol='town', outputCol='town_encoded')
country_model = feature.StringIndexer(inputCol='country', outputCol='country_encoded')
category_wide = feature.StringIndexer(inputCol='category_mapped', outputCol='category_wide_encoded')

vector_assembler = feature.VectorAssembler(inputCols=['device_id', 'app_id', 'label_id', 'event_id', 'longitude', 'latitude', 'is_active', 'age', 
                                                            'day', 'hour', 'minute', 'second', 'category_encoded', 'category_wide_encoded', 'phone_brand_encoded',\
                                                     'is_active_encoded', 'device_model_encoded'],
                                        outputCol='features')
logistic = classification.LogisticRegression(labelCol='gender_label', featuresCol='features')

lr_model = Pipeline(stages=[indexer, category,category_wide, brand, group, is_active, device_model, town_model, country_model, vector_assembler, logistic])

predicted = lr_model.fit(training).transform(test)


evaluator = BinaryClassificationEvaluator(labelCol='gender_label')
evaluator.evaluate(predicted)
# Out:
# 0.5991459815762952

# %%
#Random Forest
from pyspark.ml.evaluation import BinaryClassificationEvaluator, \
    MulticlassClassificationEvaluator, \
    RegressionEvaluator

indexer = feature.StringIndexer(inputCol="gender", outputCol="gender_label")
category = feature.StringIndexer(inputCol='category', outputCol='category_encoded')
brand = feature.StringIndexer(inputCol='phone_brand', outputCol='phone_brand_encoded')
group = feature.StringIndexer(inputCol='group', outputCol='group_encoded')
is_active = feature.StringIndexer(inputCol='is_active', outputCol='is_active_encoded')
device_model = feature.StringIndexer(inputCol='device_model', outputCol='device_model_encoded')
town_model = feature.StringIndexer(inputCol='town', outputCol='town_encoded')
country_model = feature.StringIndexer(inputCol='country', outputCol='country_encoded')
category_wide = feature.StringIndexer(inputCol='category_mapped', outputCol='category_wide_encoded')

vector_assembler = feature.VectorAssembler(inputCols=['device_id', 'app_id', 'label_id', 'event_id', 'longitude', 'latitude', 'is_active', 'age', 
                                                            'day', 'hour', 'minute', 'second', 'category_wide_encoded', 'phone_brand_encoded',\
                                                     'is_active_encoded'],
                                        outputCol='features')

rf = classification.RandomForestClassifier(labelCol='gender_label', featuresCol='features')
random_forest_pipeline = Pipeline(stages=[indexer, category_wide, brand, group, is_active, device_model, country_model, vector_assembler, rf])
rf_prediction = random_forest_pipeline.fit(training).transform(test)

evaluator = BinaryClassificationEvaluator(labelCol='gender_label')
evaluator.evaluate(rf_prediction)
# Out:
# 0.7256918385442579
