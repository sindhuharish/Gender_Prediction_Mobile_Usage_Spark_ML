# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
import pandas as pd
import sys
import os
from pyspark.sql.functions import isnan, when, count, col
from pyspark.sql.functions import to_timestamp
import time
from pyspark.sql import functions as fn

import datetime
from pyspark.sql.functions import year, month, dayofmonth, hour, minute, second
from pyspark.mllib.stat import Statistics
import pandas as pd

# %%
spark = SparkSession.builder.appName('data-cleaning').\
                        config("spark.executor.instances", '3').\
                        config("spark.executor.memory", '40g').\
                        config('spark.executor.cores', '5').\
                        config('spark.cores.max', '5').appName('data_clean').\
                        getOrCreate()

# %%
sqlContext = SQLContext(spark.sparkContext)

# %%
train_data = spark.read.format('csv').option('header', 'true').load('../modeled_data/train_with_geo.csv')

# %%
train_data.count()
# Out:
# 129799

# %%
train_data = train_data.drop('latitude18').drop('longitude19').drop('_c0').withColumnRenamed('latitude5', 'latitude').withColumnRenamed('longitude4', 'longitude')
train_data.limit(5).toPandas()
# Out:
#            app_id      device_id label_id event_id longitude latitude  \
# 0  -1.4565846e+17  -4.968155e+18    713.0   4633.0    116.38    39.96
# 1  -1.4565846e+17  -4.968155e+18    704.0   4633.0    116.38    39.96
# 2  -1.4565846e+17  -4.968155e+18    548.0   4633.0    116.38    39.96
# 3  -1.4565846e+17  -4.968155e+18    302.0   4633.0    116.38    39.96
# 4  -1.4565846e+17  -4.968155e+18    303.0   4633.0    116.38    39.96
#
#   is_active age is_installed day    ...     second gender group  \
# 0         0  53            1   1    ...          6      F  F43+
# 1         0  53            1   1    ...          6      F  F43+
# 2         0  53            1   1    ...          6      F  F43+
# 3         0  53            1   1    ...          6      F  F43+
# 4         0  53            1   1    ...          6      F  F43+
#
#                 category phone_brand device_model     town country  \
# 0             Services 1      Huawei     荣耀6 Plus  Beijing   China
# 1  Property Industry 2.0      Huawei     荣耀6 Plus  Beijing   China
# 2           Industry tag      Huawei     荣耀6 Plus  Beijing   China
# 3                unknown      Huawei     荣耀6 Plus  Beijing   China
# 4                unknown      Huawei     荣耀6 Plus  Beijing   China
#
#   category_mapped town_index
# 0        industry         35
# 1        industry         35
# 2        industry         35
# 3           other         35
# 4           other         35
#
# [5 rows x 22 columns]

# %%
training, test = train_data.randomSplit([0.8, 0.2], 0)

# %%
training.count()
# Out:
# 103743

# %%
test.count()
# Out:
# 26056

# %%
from pyspark.sql.types import FloatType
from pyspark.sql.types import IntegerType

float_columns = ['device_id', 'app_id', 'label_id', 'event_id', 'longitude', 'latitude']
int_columns = ['is_active', 'age', 'is_installed', 'day', 'hour', 'minute', 'second', 'town_index']
string_columns = ['gender', 'group', 'category', 'phone_brand', 'device_model', 'town', 'country', 'category_mapped']

training = train_data.select(*(col(c).cast("float").alias(c) for c in float_columns), \
                                                 *(col(c).cast("int").alias(c) for c in int_columns), \
                                                 *(col(c).alias(c) for c in string_columns))
test = train_data.select(*(col(c).cast("float").alias(c) for c in float_columns), \
                                                 *(col(c).cast("int").alias(c) for c in int_columns), \
                                                 *(col(c).alias(c) for c in string_columns))

# %%
training.printSchema()
# Out:
# root
#  |-- device_id: float (nullable = true)
#  |-- app_id: float (nullable = true)
#  |-- label_id: float (nullable = true)
#  |-- event_id: float (nullable = true)
#  |-- longitude: float (nullable = true)
#  |-- latitude: float (nullable = true)
#  |-- is_active: integer (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- is_installed: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- minute: integer (nullable = true)
#  |-- second: integer (nullable = true)
#  |-- town_index: integer (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- group: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- phone_brand: string (nullable = true)
#  |-- device_model: string (nullable = true)
#  |-- town: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- category_mapped: string (nullable = true)

# %%
#Correlation
indexer = feature.StringIndexer(inputCol="gender", outputCol="gender_label")
category = feature.StringIndexer(inputCol='category', outputCol='category_encoded')
brand = feature.StringIndexer(inputCol='phone_brand', outputCol='phone_brand_encoded')
group = feature.StringIndexer(inputCol='group', outputCol='group_encoded')
is_active = feature.StringIndexer(inputCol='is_active', outputCol='is_active_encoded')
device_model = feature.StringIndexer(inputCol='device_model', outputCol='device_model_encoded')
town_model = feature.StringIndexer(inputCol='town', outputCol='town_encoded')
country_model = feature.StringIndexer(inputCol='country', outputCol='country_encoded')
category_wide = feature.StringIndexer(inputCol='category_mapped', outputCol='category_wide_encoded')

correlation_pipeline = Pipeline(stages=[indexer, category,category_wide, brand, group, is_active, device_model, town_model, country_model])
encoded_data = correlation_pipeline.fit(training).transform(training)

encoded_data = encoded_data['gender_label','device_id', 'app_id', 'category_encoded', 'category_wide_encoded', 'phone_brand_encoded', 'group_encoded', 'is_active_encoded', 'device_model_encoded',\
                           'town_encoded', 'country_encoded', 'label_id', 'event_id', 'longitude', 'latitude', 'day', 'hour', 'minute']
col_names = encoded_data.columns
features = encoded_data.rdd.map(lambda row: row[0:])
features
corr_mat=Statistics.corr(features, method="pearson")
corr_df = pd.DataFrame(corr_mat)

corr_df.columns = col_names

corr = corr_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col0 {
#             background-color:  #b40426;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col1 {
#             background-color:  #5d7ce6;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col2 {
#             background-color:  #506bda;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col3 {
#             background-color:  #7699f6;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col4 {
#             background-color:  #b9d0f9;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col5 {
#             background-color:  #6e90f2;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col6 {
#             background-color:  #ba162b;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col7 {
#             background-color:  #97b8ff;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col8 {
#             background-color:  #7295f4;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col9 {
#             background-color:  #536edd;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col10 {
#             background-color:  #bad0f8;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col11 {
#             background-color:  #a7c5fe;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col12 {
#             background-color:  #3b4cc0;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col13 {
#             background-color:  #9fbfff;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col14 {
#             background-color:  #8db0fe;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col15 {
#             background-color:  #5673e0;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col16 {
#             background-color:  #5e7de7;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row0_col17 {
#             background-color:  #4a63d3;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col0 {
#             background-color:  #5b7ae5;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col1 {
#             background-color:  #b40426;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col2 {
#             background-color:  #5977e3;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col3 {
#             background-color:  #7b9ff9;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col4 {
#             background-color:  #b3cdfb;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col5 {
#             background-color:  #6788ee;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col6 {
#             background-color:  #5a78e4;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col7 {
#             background-color:  #6180e9;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col8 {
#             background-color:  #5875e1;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col9 {
#             background-color:  #3b4cc0;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col10 {
#             background-color:  #bed2f6;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col11 {
#             background-color:  #bbd1f8;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col12 {
#             background-color:  #4358cb;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col13 {
#             background-color:  #abc8fd;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col14 {
#             background-color:  #93b5fe;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col15 {
#             background-color:  #6384eb;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col16 {
#             background-color:  #5977e3;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row1_col17 {
#             background-color:  #5e7de7;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col0 {
#             background-color:  #4a63d3;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col1 {
#             background-color:  #5470de;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col2 {
#             background-color:  #b40426;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col3 {
#             background-color:  #6180e9;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col4 {
#             background-color:  #aac7fd;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col5 {
#             background-color:  #6e90f2;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col6 {
#             background-color:  #4c66d6;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col7 {
#             background-color:  #a9c6fd;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col8 {
#             background-color:  #6180e9;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col9 {
#             background-color:  #485fd1;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col10 {
#             background-color:  #b5cdfa;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col11 {
#             background-color:  #bed2f6;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col12 {
#             background-color:  #4257c9;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col13 {
#             background-color:  #afcafc;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col14 {
#             background-color:  #9bbcff;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col15 {
#             background-color:  #536edd;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col16 {
#             background-color:  #5e7de7;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row2_col17 {
#             background-color:  #4a63d3;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col0 {
#             background-color:  #4a63d3;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col1 {
#             background-color:  #506bda;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col2 {
#             background-color:  #3b4cc0;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col3 {
#             background-color:  #b40426;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col4 {
#             background-color:  #ed8366;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col5 {
#             background-color:  #6687ed;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col6 {
#             background-color:  #4e68d8;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col7 {
#             background-color:  #3b4cc0;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col8 {
#             background-color:  #516ddb;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col9 {
#             background-color:  #4257c9;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col10 {
#             background-color:  #b3cdfb;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col11 {
#             background-color:  #7b9ff9;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col12 {
#             background-color:  #455cce;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col13 {
#             background-color:  #b3cdfb;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col14 {
#             background-color:  #a1c0ff;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col15 {
#             background-color:  #4c66d6;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col16 {
#             background-color:  #5572df;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row3_col17 {
#             background-color:  #6485ec;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row4_col0 {
#             background-color:  #5673e0;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row4_col1 {
#             background-color:  #4f69d9;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row4_col2 {
#             background-color:  #4961d2;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac110009row4_col3 {
#             background-color:  #f4987a;
#         }    #T_8d1c6b6e_4f88_11e9_9c31_0242ac1

# %%
from pyspark.ml import Pipeline
from pyspark.ml import feature
from pyspark.ml import classification
from pyspark.ml.evaluation import BinaryClassificationEvaluator, \
    MulticlassClassificationEvaluator, \
    RegressionEvaluator

# %%
#Logistic
indexer = feature.StringIndexer(inputCol="gender", outputCol="gender_label")
category = feature.StringIndexer(inputCol='category', outputCol='category_encoded')
brand = feature.StringIndexer(inputCol='phone_brand', outputCol='phone_brand_encoded')
group = feature.StringIndexer(inputCol='group', outputCol='group_encoded')
is_active = feature.StringIndexer(inputCol='is_active', outputCol='is_active_encoded')
device_model = feature.StringIndexer(inputCol='device_model', outputCol='device_model_encoded')
town_model = feature.StringIndexer(inputCol='town', outputCol='town_encoded')
country_model = feature.StringIndexer(inputCol='country', outputCol='country_encoded')
category_wide = feature.StringIndexer(inputCol='category_mapped', outputCol='category_wide_encoded')

vector_assembler = feature.VectorAssembler(inputCols=['device_id', 'app_id', 'label_id', 'event_id', 'longitude', 'latitude', 'is_active', 'age', 
                                                            'day', 'hour', 'minute', 'second', 'category_encoded', 'category_wide_encoded', 'phone_brand_encoded',\
                                                     'is_active_encoded', 'device_model_encoded'],
                                        outputCol='features')
logistic = classification.LogisticRegression(labelCol='gender_label', featuresCol='features')

lr_model = Pipeline(stages=[indexer, category,category_wide, brand, group, is_active, device_model, town_model, country_model, vector_assembler, logistic])

predicted = lr_model.fit(training).transform(test)


evaluator = BinaryClassificationEvaluator(labelCol='gender_label')
evaluator.evaluate(predicted)
# Out:
# 0.5991459815762952

# %%
#Random Forest
from pyspark.ml.evaluation import BinaryClassificationEvaluator, \
    MulticlassClassificationEvaluator, \
    RegressionEvaluator

indexer = feature.StringIndexer(inputCol="gender", outputCol="gender_label")
category = feature.StringIndexer(inputCol='category', outputCol='category_encoded')
brand = feature.StringIndexer(inputCol='phone_brand', outputCol='phone_brand_encoded')
group = feature.StringIndexer(inputCol='group', outputCol='group_encoded')
is_active = feature.StringIndexer(inputCol='is_active', outputCol='is_active_encoded')
device_model = feature.StringIndexer(inputCol='device_model', outputCol='device_model_encoded')
town_model = feature.StringIndexer(inputCol='town', outputCol='town_encoded')
country_model = feature.StringIndexer(inputCol='country', outputCol='country_encoded')
category_wide = feature.StringIndexer(inputCol='category_mapped', outputCol='category_wide_encoded')

vector_assembler = feature.VectorAssembler(inputCols=['device_id', 'app_id', 'label_id', 'event_id', 'longitude', 'latitude', 'is_active', 'age', 
                                                            'day', 'hour', 'minute', 'second', 'category_wide_encoded', 'phone_brand_encoded',\
                                                     'is_active_encoded'],
                                        outputCol='features')

rf = classification.RandomForestClassifier(labelCol='gender_label', featuresCol='features')
random_forest_pipeline = Pipeline(stages=[indexer, category_wide, brand, group, is_active, device_model, country_model, vector_assembler, rf])
rf_prediction = random_forest_pipeline.fit(training).transform(test)

evaluator = BinaryClassificationEvaluator(labelCol='gender_label')
evaluator.evaluate(rf_prediction)
# Out:
# 0.7256918385442579
